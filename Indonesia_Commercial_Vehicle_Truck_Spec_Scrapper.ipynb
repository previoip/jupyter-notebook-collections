# %% [markdown]
# <a href="https://colab.research.google.com/github/previoip/web-scrapper-collections/blob/main/Indonesia_Commercial_Vehicle_Truck_Spec_Scrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests, os, shutil

# %%
cache_folder = './cache'
result_folder = './result'
alias_correction_file = './aliases.txt'

csv_delim = ';'
csv_delim_alt = ','

download_result = True
download_cache = False

# %%
def mkdir(path: str):
    if not os.path.exists(path) or not os.path.isdir(path):
        os.mkdir(path)

def url2fn(url: str):
    while url.endswith('/'):
        url = url[:-1]
    for r in ['https://', 'http://', 'ftps://', 'ftp://']:
        url = url.replace(r, '')
    for r in ['.', '?', '%']:
        url = url.replace(r, '-')
    url = url.replace('/', '_')
    return url

def norm_val(val: str):
  for n in ['\n\r', '\n', '\r', '\t']:
    val = val.replace(n, '')
  val = val.replace(csv_delim, csv_delim_alt)
  return val.strip()

def get_html_content(url, cache_response=True, strict=True) -> bytes:
    print(f'processing: {url}')

    fname = url2fn(url) + '.html'
    cache_path = os.path.join(cache_folder, fname)
    data = None

    def request(url, strict=False):
        res = requests.get(url, verify=False)
        if not res.status_code == 200:
            if not strict:
                return None
            else:
                res.raise_for_status()
                exit(1)
        return res.content

    if cache_response:
        mkdir(cache_folder)
        cache_path = os.path.join(cache_folder, fname)
        if os.path.exists(cache_path):
            print(f'using cached result: {cache_path}')
            with open(cache_path, 'rb') as fp:
                data = fp.read()
        else:
            print(f'caching requested result: {fname}')
            data = request(url)
            with open(cache_path, 'wb') as fp:
                fp.write(data)
    else:
        data = request(url)
    return data

def bs4htmlParser(url):
    return BeautifulSoup(get_html_content(url), 'html.parser')

def parseAlias(textfp: str):
  a = [[None, None, None, None]]
  if os.path.exists(textfp) and os.path.isfile(textfp):
    with open(textfp, 'r') as fp:
      a = [i.split('\t') for i in fp.read().split('\n')]
    a = [i for i in a if len(i)==4]
    r = {}
    for b in a:
      if not r.get(b[0]):
        r[b[0]] = {}
      r[b[0]][b[1]] = [b[2], b[3]]
  return r

def correct_alias(alias, category, param):
  cat = alias.get(category)
  if cat:
    res = cat.get(param)
    if res:
      return res

  return category, param

# %%
mkdir(result_folder)

# %%
alias = parseAlias('aliases.txt')

# %% [markdown]
# # Isuzu Astra Lineup

# %%
url = 'https://isuzu-astra.com/'

# %%
ret = csv_delim.join(['Manufacturer', 'Emission Standard', 'Series', 'Variant', 'Specification Category', 'Specification Parameter', 'Unit', 'Value'])
ret += '\n'

page = bs4htmlParser(url)
product_dropdown = [i for i in page.find_all('div', {'class':'fNavMobileMenu'}) if 'PRODUCTS' in i.find('div', {'class':'fNavMobileTitle'}).text][0]

for product_link in product_dropdown.find_all('a'):
  vehicle_series = product_link.text.strip()
  vehicle_series_link = product_link['href']
  vehicle_series_page = bs4htmlParser(vehicle_series_link)
  vehicle_spec_list = vehicle_series_page.find(class_='vehicleSpecificationList').find(class_='row')
  row = []
  for n, i in enumerate(vehicle_spec_list.find_all(class_="accordion-item")):
    spec_category = i.find('h5').text
    units = [j.text.strip() if j else '-' for j in i.find_all(class_="col-1")]
    subcategories = [j.text.strip() if j else '-' for j in i.find_all(class_="col-3")]
    values = [j.text.strip() if j else '-' for j in i.find_all(class_="col-2")]
    len_values = len(values)
    row.append((spec_category, subcategories, units, values))
  
  vehicle_variants = row.pop(0)[-1]
  vehicle_variants_count = len(vehicle_variants)
  


  for n in range(vehicle_variants_count):
    variant = vehicle_variants[n]
    for spec_category, subcategories, units, values in row:
      # print(spec_category, subcategories, units, values[n::vehicle_variants_count])
      v_values = values[n::vehicle_variants_count]
      for m, v in enumerate(v_values):
        corrected_category, corrected_sub_category = correct_alias(alias, spec_category, subcategories[m])
        ret += csv_delim.join(['IAMI', 'euro4', vehicle_series, variant, corrected_category, corrected_sub_category, units[m], norm_val(v)])
        ret += '\n'

with open(os.path.join(result_folder, 'isuzu_astra_lineup_data.csv'), 'w') as fp:
  fp.write(ret)
# Out:
# processing: https://isuzu-astra.com/
# using cached result: ./cache/isuzu-astra-com.html
# processing: https://isuzu-astra.com/traga-pick-up
# using cached result: ./cache/isuzu-astra-com_traga-pick-up.html
# processing: https://isuzu-astra.com/all-new-isuzu-d-max/
# using cached result: ./cache/isuzu-astra-com_all-new-isuzu-d-max.html
# processing: https://isuzu-astra.com/elf-nlr/
# using cached result: ./cache/isuzu-astra-com_elf-nlr.html
# processing: https://isuzu-astra.com/elf-nmr/
# using cached result: ./cache/isuzu-astra-com_elf-nmr.html
# processing: https://isuzu-astra.com/elf-nps/
# using cached result: ./cache/isuzu-astra-com_elf-nps.html
# processing: https://isuzu-astra.com/giga-fvr/
# using cached result: ./cache/isuzu-astra-com_giga-fvr.html
# processing: https://isuzu-astra.com/giga-fvm/
# using cached result: ./cache/isuzu-astra-com_giga-fvm.html
# processing: https://isuzu-astra.com/giga-fvz/
# using cached result: ./cache/isuzu-astra-com_giga-fvz.html
# processing: https://isuzu-astra.com/giga-gxz/
# using cached result: ./cache/isuzu-astra-com_giga-gxz.html
# processing: https://isuzu-astra.com/elf-microbus/
# using cached result: ./cache/isuzu-astra-com_elf-microbus.html
# processing: https://isuzu-astra.com/elf-nqr/
# using cached result: ./cache/isuzu-astra-com_elf-nqr.html
# processing: https://isuzu-astra.com/giga-frr/
# using cached result: ./cache/isuzu-astra-com_giga-frr.html
# processing: https://isuzu-astra.com/giga-ftr/
# using cached result: ./cache/isuzu-astra-com_giga-ftr.html
# processing: https://isuzu-astra.com/traga-blind-van/
# using cached result: ./cache/isuzu-astra-com_traga-blind-van.html
# processing: https://isuzu-astra.com/all-new-isuzu-mu-x-4x4/
# using cached result: ./cache/isuzu-astra-com_all-new-isuzu-mu-x-4x4.html

# %% [markdown]
# # Hino Lineup

# %%
url = 'https://hino.co.id/'

# %%
page = bs4htmlParser(url)
a_elems = page.find_all('a')
product_list_links = []
for i in a_elems:
    i = i['href']
    if 'product-list' in i and i not in product_list_links and 'www' not in i:
        product_list_links.append(i)
        product_list_links.append(i.replace('euro4/', '')) # euro2

ret = csv_delim.join(['Manufacturer', 'Emission Standard', 'Series', 'Variant', 'Specification Category', 'Specification Parameter', 'Unit', 'Value'])
ret += '\n'

for product_link in product_list_links:
    data = bs4htmlParser(product_link)
    emmision_type = 'euro2'
    if 'euro4' in product_link:
      emmision_type = 'euro4'
    vehicle_series = data.body.find_all('section', style="padding:50px 0 0;")[0].find('h3').text
    content_body = data.body.find_all('section', style="padding-bottom: 100px;")[0]

    for item in content_body.find_all('a'):
        item_link = item.get('href')

        vehicle_variant = item.find('label').text

        data = bs4htmlParser(item_link)
        data_spec = data.find('div', id='accordion')
        for data_item in data_spec.find_all('div', {'class':'panel panel-default'}):
          spec_category = data_item.find('h4').text.strip()
          spec_imgs = data_item.find_all('img')

          
          for tab_panel in data_item.find_all('div', {'role': 'tabpanel'}):
            
              tdata = []
              table = data_item.find('div', {'role':'tabpanel'})
              table_body = table.find('tbody')
              if not table_body:
                break
              rows = table_body.find_all('tr')
              for row in rows:
                  cols = row.find_all('td')
                  cols = [ele.text.strip() for ele in cols]
                  tdata.append([ele for ele in cols if ele])

              # puts data as str into buffer
              for row in tdata:
                param, unit, val = row
                corrected_category, corrected_param = correct_alias(alias, spec_category, param)
                ret += csv_delim.join(['HINO', emmision_type, vehicle_series, vehicle_variant, corrected_category, corrected_param, unit, norm_val(val)])
                ret += '\n'

with open(os.path.join(result_folder, 'hino_lineup_data.csv'), 'w') as fp:
  fp.write(ret)
# Out:
# processing: https://hino.co.id/
# using cached result: ./cache/hino-co-id.html
# processing: https://hino.co.id/product-list/euro4/1
# using cached result: ./cache/hino-co-id_product-list_euro4_1.html
# processing: https://hino.co.id/product-detail/euro4/1/136-hd-xpower
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_136-hd-xpower.html
# processing: https://hino.co.id/product-detail/euro4/1/136-hdx-mixer
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_136-hdx-mixer.html
# processing: https://hino.co.id/product-detail/euro4/1/136-hdl
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_136-hdl.html
# processing: https://hino.co.id/product-detail/euro4/1/115-sd-std
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_115-sd-std.html
# processing: https://hino.co.id/product-detail/euro4/1/136-hd
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_136-hd.html
# processing: https://hino.co.id/product-detail/euro4/1/115-sdl-std
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_115-sdl-std.html
# processing: https://hino.co.id/product-detail/euro4/1/115-ld-std
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_115-ld-std.html
# processing: https://hino.co.id/product-detail/euro4/1/136-MD-STD
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_136-MD-STD.html
# processing: https://hino.co.id/product-detail/euro4/1/136-mdl-std
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_136-mdl-std.html
# processing: https://hino.co.id/product-detail/euro4/1/115hd
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_115hd.html
# processing: https://hino.co.id/product-detail/euro4/1/136hd
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_136hd.html
# processing: https://hino.co.id/product-detail/euro4/1/136hd-lsd
# using cached result: ./cache/hino-co-id_product-detail_euro4_1_136hd-lsd.html
# processing: https://hino.co.id/product-list/1
# using cached result: ./cache/hino-co-id_product-list_1.html
# processing: https://hino.co.id/product-detail/1/110-sd-new
# using cached result: ./cache/hino-co-id_product-detail_1_110-sd-new.html
# processing: https://hino.co.id/product-detail/1/110-sdr-new
# using cached result: ./cache/hino-co-id_product-detail_1_110-sdr-new.html
# processing: https://hino.co.id/product-detail/1/dutro-110-sdl
# using cached result: ./cache/hino-co-id_product-detail_1_dutro-110-sdl.html
# processing: https://hino.co.id/product-detail/1/dutro-110-ld
# using cached result: ./cache/hino-co-id_product-detail_1_dutro-110-ld.html
# processing: https://hino.co.id/product-detail/1/dutro-110-ldl
# using cached result: ./cache/hino-co-id_product-detail_1_dutro-110-ldl.html
# processing: https://hino.co.id/product-detail/1/dutro-130-md
# using cached result: ./cache/hino-co-id_product-detail_1_dutro-130-md.html
# processing: https://hino.co.id/product-detail/1/dutro-130-mdl
# using cached result: ./cache/hino-co-id_product-detail_1_dutro-130-mdl.html
# processing: https://hino.co.id/product-detail/1/130-hd-cargo-new
# using cached result: ./cache/hino-co-id_product-detail_1_130-hd-cargo-new.html
# processing: https://hino.co.id/product-detail/1/130-hdl-cargo-new
# using cached result: ./cache/hino-co-id_product-detail_1_130-hdl-cargo-new.html
# processing: https://hino.co.id/product-detail/1/dutro-110-hd
# using cached result: ./cache/hino-co-id_product-detail_1_dutro-110-hd.html
# processing: https://hino.co.id/product-detail/1/dutro-130-hd
# using cached result: ./cache/hino-co-id_product-detail_1_dutro-130-hd.html
# processing: https://hino.co.id/product-detail/1/130-hd-x-power-new
# using cached result: ./cache/hino-co-id_product-detail_1_130-hd-x-power-new.html
# processing: https://hino.co.id/product-detail/1/130-hd-lsd-new
# using cached result: ./cache/hino-co-id_product-detail_1_130-hd-lsd-new.html
# processing: https://hino.co.id/product-detail/1/dutro-130-hd-mixer
# using cached result: ./cache/hino-co-id_product-detail_1_dutro-130-hd-mixer.html
# processing: https://hino.co.id/product-detail/1/dutro-130-hd-4-x-4
# using cached result: ./cache/hino-co-id_product-detail_1_dutro-130-hd-4-x-4.html
# processing: https://hino.co.id/product-detail/1/dutro-130-hd-plantation
# using cached result: ./cache/hino-co-id_product-detail_1_dutro-130-hd-plantation.html
# processing: https://hino.co.id/product-list/euro4/2
# using cached result: ./cache/hino-co-id_product-list_euro4_2.html
# processing: https://hino.co.id/product-detail/euro4/2/flx-280-jw
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_flx-280-jw.html
# processing: https://hino.co.id/product-detail/euro4/2/fmx-280-th
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fmx-280-th.html
# processing: https://hino.co.id/product-detail/euro4/2/fg-260-ju
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fg-260-ju.html
# processing: https://hino.co.id/product-detail/euro4/2/fg-260-th
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fg-260-th.html
# processing: https://hino.co.id/product-detail/euro4/2/sg-280-th-abs
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_sg-280-th-abs.html
# processing: https://hino.co.id/product-detail/euro4/2/fm-280-th
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fm-280-th.html
# processing: https://hino.co.id/product-detail/euro4/2/fm-340-th
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fm-340-th.html
# processing: https://hino.co.id/product-detail/euro4/2/fle260jw
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fle260jw.html
# processing: https://hino.co.id/product-detail/euro4/2/fg-260-jj
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fg-260-jj.html
# processing: https://hino.co.id/product-detail/euro4/2/fm-260-jd
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fm-260-jd.html
# processing: https://hino.co.id/product-detail/euro4/2/fm-280-jd
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fm-280-jd.html
# processing: https://hino.co.id/product-detail/euro4/2/fm-280-jd-abs
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fm-280-jd-abs.html
# processing: https://hino.co.id/product-detail/euro4/2/fm-280-jd-mining-spec
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fm-280-jd-mining-spec.html
# processing: https://hino.co.id/product-detail/euro4/2/fm-340-pl
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fm-340-pl.html
# processing: https://hino.co.id/product-detail/euro4/2/fm-340-pd
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fm-340-pd.html
# processing: https://hino.co.id/product-detail/euro4/2/fm-280-jm
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fm-280-jm.html
# processing: https://hino.co.id/product-detail/euro4/2/fm-280-jl
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fm-280-jl.html
# processing: https://hino.co.id/product-detail/euro4/2/fg-240-jp
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fg-240-jp.html
# processing: https://hino.co.id/product-detail/euro4/2/fg-260-jp
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fg-260-jp.html
# processing: https://hino.co.id/product-detail/euro4/2/fg-260-jk
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fg-260-jk.html
# processing: https://hino.co.id/product-detail/euro4/2/fg-260-jl
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fg-260-jl.html
# processing: https://hino.co.id/product-detail/euro4/2/fg-260-jm-eiv
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fg-260-jm-eiv.html
# processing: https://hino.co.id/product-detail/euro4/2/fg-260-js
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fg-260-js.html
# processing: https://hino.co.id/product-detail/euro4/2/fl-260-jn
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fl-260-jn.html
# processing: https://hino.co.id/product-detail/euro4/2/fl-260-jw-eiv
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fl-260-jw-eiv.html
# processing: https://hino.co.id/product-detail/euro4/2/fl-280-jt
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fl-280-jt.html
# processing: https://hino.co.id/product-detail/euro4/2/fl-280-jw
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fl-280-jw.html
# processing: https://hino.co.id/product-detail/euro4/2/fm-280-jw
# using cached result: ./cache/hino-co-id_product-detail_euro4_2_fm-280-jw.html
# processing: https://hino.co.id/product-list/2
# using cached result: ./cache/hino-co-id_product-list_2.html
# processing: https://hino.co.id/product-detail/2/hino-ranger-flx260jw-8x2
# using cached result: ./cache/hino-co-id_product-detail_2_hino-ranger-flx260jw-8x2.html
# processing: https://hino.co.id/product-detail/2/fg-235-ju
# using cached result: ./cache/hino-co-id_product-detail_2_fg-235-ju.html
# processing: https://hino.co.id/product-detail/2/fc-190-j
# using cached result: ./cache/hino-co-id_product-detail_2_fc-190-j.html
# processing: https://hino.co.id/product-detail/2/fg-235-jk-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-235-jk-new.html
# processing: https://hino.co.id/product-detail/2/fg-245-jk-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-245-jk-new.html
# processing: https://hino.co.id/product-detail/2/fg-245-jk-new-with-abs-system
# using cached result: ./cache/hino-co-id_product-detail_2_fg-245-jk-new-with-abs-system.html
# processing: https://hino.co.id/product-detail/2/fg-235-jl-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-235-jl-new.html
# processing: https://hino.co.id/product-detail/2/fg-245-jl-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-245-jl-new.html
# processing: https://hino.co.id/product-detail/2/fg-235-jp-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-235-jp-new.html
# processing: https://hino.co.id/product-detail/2/fg-245-jp
# using cached result: ./cache/hino-co-id_product-detail_2_fg-245-jp.html
# processing: https://hino.co.id/product-detail/2/fg-235-js-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-235-js-new.html
# processing: https://hino.co.id/product-detail/2/fg-245-jp-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-245-jp-new.html
# processing: https://hino.co.id/product-detail/2/fg-260-jm-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-260-jm-new.html
# processing: https://hino.co.id/product-detail/2/fg-265-jm-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-265-jm-new.html
# processing: https://hino.co.id/product-detail/2/fl-235-jn-new
# using cached result: ./cache/hino-co-id_product-detail_2_fl-235-jn-new.html
# processing: https://hino.co.id/product-detail/2/fl-245-jn
# using cached result: ./cache/hino-co-id_product-detail_2_fl-245-jn.html
# processing: https://hino.co.id/product-detail/2/fl-245-jn-new
# using cached result: ./cache/hino-co-id_product-detail_2_fl-245-jn-new.html
# processing: https://hino.co.id/product-detail/2/fl-260-jt-new
# using cached result: ./cache/hino-co-id_product-detail_2_fl-260-jt-new.html
# processing: https://hino.co.id/product-detail/2/fl-235-jw-new
# using cached result: ./cache/hino-co-id_product-detail_2_fl-235-jw-new.html
# processing: https://hino.co.id/product-detail/2/fm-245-jw-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-245-jw-new.html
# processing: https://hino.co.id/product-detail/2/fl-245-jw-new-with-abs-system
# using cached result: ./cache/hino-co-id_product-detail_2_fl-245-jw-new-with-abs-system.html
# processing: https://hino.co.id/product-detail/2/fl-260-jw-new
# using cached result: ./cache/hino-co-id_product-detail_2_fl-260-jw-new.html
# processing: https://hino.co.id/product-detail/2/fl-265-jw-new
# using cached result: ./cache/hino-co-id_product-detail_2_fl-265-jw-new.html
# processing: https://hino.co.id/product-detail/2/fm-260-jw-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-260-jw-new.html
# processing: https://hino.co.id/product-detail/2/fm-285-jw-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-285-jw-new.html
# processing: https://hino.co.id/product-detail/2/fg-235-jj-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-235-jj-new.html
# processing: https://hino.co.id/product-detail/2/fm-235-jd-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-235-jd-new.html
# processing: https://hino.co.id/product-detail/2/fm-260-jd-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-260-jd-new.html
# processing: https://hino.co.id/product-detail/2/fm-260-jd-new-mining
# using cached result: ./cache/hino-co-id_product-detail_2_fm-260-jd-new-mining.html
# processing: https://hino.co.id/product-detail/2/fm-285-jd-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-285-jd-new.html
# processing: https://hino.co.id/product-detail/2/fm-350-pl-mining-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-350-pl-mining-new.html
# processing: https://hino.co.id/product-detail/2/fm-350-pd-mining-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-350-pd-mining-new.html
# processing: https://hino.co.id/product-detail/2/fm-260-jm-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-260-jm-new.html
# processing: https://hino.co.id/product-detail/2/fm-285-jm-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-285-jm-new.html
# processing: https://hino.co.id/product-detail/2/gy-350-pu-new
# using cached result: ./cache/hino-co-id_product-detail_2_gy-350-pu-new.html
# processing: https://hino.co.id/product-detail/2/fg-235-th-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-235-th-new.html
# processing: https://hino.co.id/product-detail/2/fg-245-th-new
# using cached result: ./cache/hino-co-id_product-detail_2_fg-245-th-new.html
# processing: https://hino.co.id/product-detail/2/sg-260-th-new
# using cached result: ./cache/hino-co-id_product-detail_2_sg-260-th-new.html
# processing: https://hino.co.id/product-detail/2/sg-260-th-new-complete-with-abs-system
# using cached result: ./cache/hino-co-id_product-detail_2_sg-260-th-new-complete-with-abs-system.html
# processing: https://hino.co.id/product-detail/2/sg-285-t-h-new
# using cached result: ./cache/hino-co-id_product-detail_2_sg-285-t-h-new.html
# processing: https://hino.co.id/product-detail/2/sg-285-th-new
# using cached result: ./cache/hino-co-id_product-detail_2_sg-285-th-new.html
# processing: https://hino.co.id/product-detail/2/fm-265-t-h-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-265-t-h-new.html
# processing: https://hino.co.id/product-detail/2/fm-265-th-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-265-th-new.html
# processing: https://hino.co.id/product-detail/2/fm-285-t-h-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-285-t-h-new.html
# processing: https://hino.co.id/product-detail/2/fm-285-th-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-285-th-new.html
# processing: https://hino.co.id/product-detail/2/fm-350-t-h-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-350-t-h-new.html
# processing: https://hino.co.id/product-detail/2/fm-350-th-new
# using cached result: ./cache/hino-co-id_product-detail_2_fm-350-th-new.html
# processing: https://hino.co.id/product-list/euro4/3
# using cached result: ./cache/hino-co-id_product-list_euro4_3.html
# processing: https://hino.co.id/product-detail/euro4/3/zy-5041-euro4
# using cached result: ./cache/hino-co-id_product-detail_euro4_3_zy-5041-euro4.html
# processing: https://hino.co.id/product-detail/euro4/3/zs4141-euro4
# using cached result: ./cache/hino-co-id_product-detail_euro4_3_zs4141-euro4.html
# processing: https://hino.co.id/product-list/3
# using cached result: ./cache/hino-co-id_product-list_3.html
# processing: https://hino.co.id/product-detail/3/ss1e-th
# using cached result: ./cache/hino-co-id_product-detail_3_ss1e-th.html
# processing: https://hino.co.id/product-detail/3/sv-4145
# using cached result: ./cache/hino-co-id_product-detail_3_sv-4145.html
# processing: https://hino.co.id/product-detail/3/zs-4141
# using cached result: ./cache/hino-co-id_product-detail_3_zs-4141.html
# processing: https://hino.co.id/product-detail/3/zs-4141-at
# using cached result: ./cache/hino-co-id_product-detail_3_zs-4141-at.html
# processing: https://hino.co.id/product-detail/3/zy-5041
# using cached result: ./cache/hino-co-id_product-detail_3_zy-5041.html
# processing: https://hino.co.id/product-detail/3/zy-5041-at
# using cached result: ./cache/hino-co-id_product-detail_3_zy-5041-at.html
# processing: https://hino.co.id/product-list/euro4/4
# using cached result: ./cache/hino-co-id_product-list_euro4_4.html
# processing: https://hino.co.id/product-detail/euro4/4/ak240-std
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_ak240-std.html
# processing: https://hino.co.id/product-detail/euro4/4/rk280-std
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_rk280-std.html
# processing: https://hino.co.id/product-detail/euro4/4/rk280-abs
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_rk280-abs.html
# processing: https://hino.co.id/product-detail/euro4/4/115-sdb-std
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_115-sdb-std.html
# processing: https://hino.co.id/product-detail/euro4/4/rm280-std
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_rm280-std.html
# processing: https://hino.co.id/product-detail/euro4/4/115-sdbl-std
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_115-sdbl-std.html
# processing: https://hino.co.id/product-detail/euro4/4/rm280-abs
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_rm280-abs.html
# processing: https://hino.co.id/product-detail/euro4/4/136-mdbl-std
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_136-mdbl-std.html
# processing: https://hino.co.id/product-detail/euro4/4/gb150
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_gb150.html
# processing: https://hino.co.id/product-detail/euro4/4/gb150-at
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_gb150-at.html
# processing: https://hino.co.id/product-detail/euro4/4/gb150-at
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_gb150-at.html
# processing: https://hino.co.id/product-detail/euro4/4/gb150-l-at
# using cached result: ./cache/hino-co-id_product-detail_euro4_4_gb150-l-at.html
# processing: https://hino.co.id/product-list/4
# using cached result: ./cache/hino-co-id_product-list_4.html
# processing: https://hino.co.id/product-detail/4/dutro-bus-110-sdb
# using cached result: ./cache/hino-co-id_product-detail_4_dutro-bus-110-sdb.html
# processing: https://hino.co.id/product-detail/4/dutro-bus-110-ldb
# using cached result: ./cache/hino-co-id_product-detail_4_dutro-bus-110-ldb.html
# processing: https://hino.co.id/product-detail/4/dutro-bus-130-mdbl
# using cached result: ./cache/hino-co-id_product-detail_4_dutro-bus-130-mdbl.html
# processing: https://hino.co.id/product-detail/4/fb-130
# using cached result: ./cache/hino-co-id_product-detail_4_fb-130.html
# processing: https://hino.co.id/product-detail/4/fc-bus
# using cached result: ./cache/hino-co-id_product-detail_4_fc-bus.html
# processing: https://hino.co.id/product-detail/4/a-215
# using cached result: ./cache/hino-co-id_product-detail_4_a-215.html
# processing: https://hino.co.id/product-detail/4/r-260
# using cached result: ./cache/hino-co-id_product-detail_4_r-260.html
# processing: https://hino.co.id/product-detail/4/rn-285
# using cached result: ./cache/hino-co-id_product-detail_4_rn-285.html
# processing: https://hino.co.id/product-detail/4/rn-285-at
# using cached result: ./cache/hino-co-id_product-detail_4_rn-285-at.html
# processing: https://hino.co.id/product-detail/4/r-260-as
# using cached result: ./cache/hino-co-id_product-detail_4_r-260-as.html

# %% [markdown]
# # Mitsubishi FUSO lineup

# %%
url = 'https://ktbfuso.co.id'

# %%
ret = csv_delim.join(['Manufacturer', 'Emission Standard', 'Series', 'Variant', 'Specification Category', 'Specification Parameter', 'Unit', 'Value'])
ret += '\n'

page = bs4htmlParser(url)
emmision_type = 'euro4'

elems_product_category = page.find_all(id='nav-tab')[0].find_all('a')
product_categories = [i.text for i in elems_product_category]
product_categories_links = [i['href'] for i in elems_product_category]

for n, product_url in enumerate(product_categories_links):
  product_category = product_categories[n]
  product_category_page = bs4htmlParser(product_url)
  product_cat_elem = product_category_page.find(class_='tabs_content')
  product_list_elems = product_cat_elem.find_all(class_='col-lg-custom-5 col-4 text-center col-product')

  vehicle_series = product_category_page.find('div', class_="title border_bottom_image").find('h3').text.strip()

  for el in product_list_elems:
    media = el.find('img', class_='img-fluid')['src']
    vehicle_link = el.find_all('a')[0]['href']
    vehicle_variant = el.find('div', class_="product_name mt-3").text.strip()

    variant_spec_page = bs4htmlParser(vehicle_link)

    variant_spec_category_elems = variant_spec_page.find('section', class_="spesifikasi_wrapper py-5").find('div', class_="accordion_wrapper").find_all('div', class_="accordion")
    for spec_cat_el in variant_spec_category_elems:
      spec_category = spec_cat_el.find('div', class_='title mr-auto').text
      spec_params = spec_cat_el.find_all('div', class_="row row_spec no-gutters")

      for param in spec_params:
        row = [i.text for i in param.find_all('div', class_='col-lg-4')]
        param, unit, val = row
        corrected_category, corrected_param = correct_alias(alias, spec_category, param)
        ret += csv_delim.join(['MITSUBISHI', emmision_type, vehicle_series, vehicle_variant, corrected_category, corrected_param, unit, norm_val(val)])
        ret += '\n'


with open(os.path.join(result_folder, 'mitsubishi_lineup_data.csv'), 'w') as fp:
  fp.write(ret)
# Out:
# processing: https://ktbfuso.co.id
# using cached result: ./cache/ktbfuso-co-id.html
# processing: https://ktbfuso.co.id/product-category/1/light-duty
# using cached result: ./cache/ktbfuso-co-id_product-category_1_light-duty.html
# processing: https://ktbfuso.co.id/product-detail/1/fe-71
# using cached result: ./cache/ktbfuso-co-id_product-detail_1_fe-71.html
# processing: https://ktbfuso.co.id/product-detail/2/fe-71-bc
# using cached result: ./cache/ktbfuso-co-id_product-detail_2_fe-71-bc.html
# processing: https://ktbfuso.co.id/product-detail/3/fe-71l-bcl-non-cabin
# using cached result: ./cache/ktbfuso-co-id_product-detail_3_fe-71l-bcl-non-cabin.html
# processing: https://ktbfuso.co.id/product-detail/4/fe-71l
# using cached result: ./cache/ktbfuso-co-id_product-detail_4_fe-71l.html
# processing: https://ktbfuso.co.id/product-detail/5/fe-71l-bc
# using cached result: ./cache/ktbfuso-co-id_product-detail_5_fe-71l-bc.html
# processing: https://ktbfuso.co.id/product-detail/6/fe-73
# using cached result: ./cache/ktbfuso-co-id_product-detail_6_fe-73.html
# processing: https://ktbfuso.co.id/product-detail/7/fe-74
# using cached result: ./cache/ktbfuso-co-id_product-detail_7_fe-74.html
# processing: https://ktbfuso.co.id/product-detail/8/fe-74-hd
# using cached result: ./cache/ktbfuso-co-id_product-detail_8_fe-74-hd.html
# processing: https://ktbfuso.co.id/product-detail/9/fe-74l
# using cached result: ./cache/ktbfuso-co-id_product-detail_9_fe-74l.html
# processing: https://ktbfuso.co.id/product-detail/10/fe-74-hds
# using cached result: ./cache/ktbfuso-co-id_product-detail_10_fe-74-hds.html
# processing: https://ktbfuso.co.id/product-detail/1/fe-71
# using cached result: ./cache/ktbfuso-co-id_product-detail_1_fe-71.html
# processing: https://ktbfuso.co.id/product-detail/6/fe-73
# using cached result: ./cache/ktbfuso-co-id_product-detail_6_fe-73.html
# processing: https://ktbfuso.co.id/product-detail/8/fe-74-hd
# using cached result: ./cache/ktbfuso-co-id_product-detail_8_fe-74-hd.html
# processing: https://ktbfuso.co.id/product-detail/12/fe-84gs
# using cached result: ./cache/ktbfuso-co-id_product-detail_12_fe-84gs.html
# processing: https://ktbfuso.co.id/product-detail/14/fe-84-shdx
# using cached result: ./cache/ktbfuso-co-id_product-detail_14_fe-84-shdx.html
# processing: https://ktbfuso.co.id/product-detail/15/fe-shdx
# using cached result: ./cache/ktbfuso-co-id_product-detail_15_fe-shdx.html
# processing: https://ktbfuso.co.id/product-detail/7/fe-74
# using cached result: ./cache/ktbfuso-co-id_product-detail_7_fe-74.html
# processing: https://ktbfuso.co.id/product-detail/10/fe-74-hds
# using cached result: ./cache/ktbfuso-co-id_product-detail_10_fe-74-hds.html
# processing: https://ktbfuso.co.id/product-detail/4/fe-71l
# using cached result: ./cache/ktbfuso-co-id_product-detail_4_fe-71l.html
# processing: https://ktbfuso.co.id/product-detail/9/fe-74l
# using cached result: ./cache/ktbfuso-co-id_product-detail_9_fe-74l.html
# processing: https://ktbfuso.co.id/product-detail/11/fe-84g
# using cached result: ./cache/ktbfuso-co-id_product-detail_11_fe-84g.html
# processing: https://ktbfuso.co.id/product-detail/2/fe-71-bc
# using cached result: ./cache/ktbfuso-co-id_product-detail_2_fe-71-bc.html
# processing: https://ktbfuso.co.id/product-detail/3/fe-71l-bcl-non-cabin
# using cached result: ./cache/ktbfuso-co-id_product-detail_3_fe-71l-bcl-non-cabin.html
# processing: https://ktbfuso.co.id/product-detail/5/fe-71l-bc
# using cached result: ./cache/ktbfuso-co-id_product-detail_5_fe-71l-bc.html
# processing: https://ktbfuso.co.id/product-detail/13/fe-84g-bc
# using cached result: ./cache/ktbfuso-co-id_product-detail_13_fe-84g-bc.html
# processing: https://ktbfuso.co.id/product-category/2/medium-duty
# using cached result: ./cache/ktbfuso-co-id_product-category_2_medium-duty.html
# processing: https://ktbfuso.co.id/product-detail/20/fm-65-fl-hi-gear
# using cached result: ./cache/ktbfuso-co-id_product-detail_20_fm-65-fl-hi-gear.html
# processing: https://ktbfuso.co.id/product-detail/21/fm-65-fs-hi-gear
# using cached result: ./cache/ktbfuso-co-id_product-detail_21_fm-65-fs-hi-gear.html
# processing: https://ktbfuso.co.id/product-detail/44/fn-62-f-hd-r
# using cached result: ./cache/ktbfuso-co-id_product-detail_44_fn-62-f-hd-r.html
# processing: https://ktbfuso.co.id/product-detail/46/fn-61-fs
# using cached result: ./cache/ktbfuso-co-id_product-detail_46_fn-61-fs.html
# processing: https://ktbfuso.co.id/product-detail/47/fm-65-fm-hi-gear
# using cached result: ./cache/ktbfuso-co-id_product-detail_47_fm-65-fm-hi-gear.html
# processing: https://ktbfuso.co.id/product-detail/49/fm-65-fsl-hi-gear
# using cached result: ./cache/ktbfuso-co-id_product-detail_49_fm-65-fsl-hi-gear.html
# processing: https://ktbfuso.co.id/product-detail/50/fm-65-fsl
# using cached result: ./cache/ktbfuso-co-id_product-detail_50_fm-65-fsl.html
# processing: https://ktbfuso.co.id/product-detail/51/fn-61-fl
# using cached result: ./cache/ktbfuso-co-id_product-detail_51_fn-61-fl.html
# processing: https://ktbfuso.co.id/product-detail/52/fn-62-fl-hd-r
# using cached result: ./cache/ktbfuso-co-id_product-detail_52_fn-62-fl-hd-r.html
# processing: https://ktbfuso.co.id/product-detail/54/fn-61-fl-hd-r
# using cached result: ./cache/ktbfuso-co-id_product-detail_54_fn-61-fl-hd-r.html
# processing: https://ktbfuso.co.id/product-detail/20/fm-65-fl-hi-gear
# using cached result: ./cache/ktbfuso-co-id_product-detail_20_fm-65-fl-hi-gear.html
# processing: https://ktbfuso.co.id/product-detail/21/fm-65-fs-hi-gear
# using cached result: ./cache/ktbfuso-co-id_product-detail_21_fm-65-fs-hi-gear.html
# processing: https://ktbfuso.co.id/product-detail/47/fm-65-fm-hi-gear
# using cached result: ./cache/ktbfuso-co-id_product-detail_47_fm-65-fm-hi-gear.html
# processing: https://ktbfuso.co.id/product-detail/49/fm-65-fsl-hi-gear
# using cached result: ./cache/ktbfuso-co-id_product-detail_49_fm-65-fsl-hi-gear.html
# processing: https://ktbfuso.co.id/product-detail/50/fm-65-fsl
# using cached result: ./cache/ktbfuso-co-id_product-detail_50_fm-65-fsl.html
# processing: https://ktbfuso.co.id/product-detail/46/fn-61-fs
# using cached result: ./cache/ktbfuso-co-id_product-detail_46_fn-61-fs.html
# processing: https://ktbfuso.co.id/product-detail/51/fn-61-fl
# using cached result: ./cache/ktbfuso-co-id_product-detail_51_fn-61-fl.html
# processing: https://ktbfuso.co.id/product-detail/54/fn-61-fl-hd-r
# using cached result: ./cache/ktbfuso-co-id_product-detail_54_fn-61-fl-hd-r.html
# processing: https://ktbfuso.co.id/product-detail/44/fn-62-f-hd-r
# using cached result: ./cache/ktbfuso-co-id_product-detail_44_fn-62-f-hd-r.html
# processing: https://ktbfuso.co.id/product-detail/52/fn-62-fl-hd-r
# using cached result: ./cache/ktbfuso-co-id_product-detail_52_fn-62-fl-hd-r.html
# processing: https://ktbfuso.co.id/product-category/3/tractor-head
# using cached result: ./cache/ktbfuso-co-id_product-category_3_tractor-head.html
# processing: https://ktbfuso.co.id/product-detail/45/fn-62-f-tractor-head
# using cached result: ./cache/ktbfuso-co-id_product-detail_45_fn-62-f-tractor-head.html
# processing: https://ktbfuso.co.id/product-detail/45/fn-62-f-tractor-head
# using cached result: ./cache/ktbfuso-co-id_product-detail_45_fn-62-f-tractor-head.html

# %% [markdown]
# # Download result

# %%
from google.colab import files

if download_cache:
  shutil.make_archive(cache_folder, 'zip', cache_folder, verbose=True)
  files.download(cache_folder + '.zip')

if download_result:
  shutil.make_archive(result_folder, 'zip', result_folder, verbose=True)
  files.download(result_folder + '.zip')
